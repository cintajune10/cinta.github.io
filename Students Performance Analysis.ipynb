# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
data = pd.read_csv('StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data.shape
# Out:
# (1000, 8)

# %%
#students passed in math exam
data['Maths_pass'] = np.where(data['math score']<47, 'F', 'P')
data.Maths_pass.value_counts()
# Out:
# P    904
# F     96
# Name: Maths_pass, dtype: int64

# %%
#students passed in reading exam
data['Reading_pass']=np.where(data['reading score']<47,'F','P')
data.Reading_pass.value_counts()
# Out:
# P    934
# F     66
# Name: Reading_pass, dtype: int64

# %%
data['Writing_pass']=np.where(data['writing score']<47,'F','P')
data.Writing_pass.value_counts()
# Out:
# P    913
# F     87
# Name: Writing_pass, dtype: int64

# %%
s = sns.countplot(x='parental level of education', data = data, hue='Maths_pass', palette='bright')

# %%
s1= sns.countplot(x='parental level of education', data = data, hue='Reading_pass', palette='bright')

# %%
s1= sns.countplot(x='parental level of education', data = data, hue='Writing_pass', palette='bright')

# %%
data.groupby('race/ethnicity').agg(['min','max','mean'])
# Out:
#                math score                 reading score                  \
#                       min  max       mean           min  max       mean
# race/ethnicity
# group A                28  100  61.629213            23  100  64.674157
# group B                 8   97  63.452632            24   97  67.352632
# group C                 0   98  64.463950            17  100  69.103448
# group D                26  100  67.362595            31  100  70.030534
# group E                30  100  73.821429            26  100  73.028571
#
#                writing score
#                          min  max       mean
# race/ethnicity
# group A                   19   97  62.674157
# group B                   15   96  65.600000
# group C                   10  100  67.827586
# group D                   32  100  70.145038
# group E                   22  100  71.407143

# %%
sns.factorplot(x='gender', y='math score', hue='reading score', data=data, kind='bar')
# Out:
# C:\Users\cinta\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
data['Total_Marks'] = data['math score']+data['reading score']+data['writing score']
data['Percentage'] = data['Total_Marks']/3

# %%
sns.factorplot('gender','math score', data=data, kind='bar')
# Out:
# C:\Users\cinta\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot('gender','reading score',data=data,kind='bar')
# Out:
# C:\Users\cinta\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot('gender','writing score',data=data,kind='bar')
# Out:
# C:\Users\cinta\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
print(data['reading score'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(data['reading score'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
list(set(data.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('O'), dtype('int64')]

# %%
data_num = data.select_dtypes(include = ['float64', 'int64'])
data_num.head()
# Out:
#    math score  reading score  writing score  Total_Marks  Percentage
# 0          72             72             74          218   72.666667
# 1          69             90             88          247   82.333333
# 2          90             95             93          278   92.666667
# 3          47             57             44          148   49.333333
# 4          76             78             75          229   76.333333

# %%
data_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021BD519D708>,
# ...
#       dtype=object)

# %%
data_num_corr = data_num.corr()['reading score'] # -1 because the latest row is SalePrice
golden_features_list = data_num_corr[abs(data_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 5 strongly correlated values:
# reading score    1.000000
# Total_Marks      0.970331
# Percentage       0.970331
# writing score    0.954598
# math score       0.817580
# Name: reading score, dtype: float64

# %%
for i in range(0, len(data_num.columns), 5):
    sns.pairplot(data=data_num,
                x_vars=data_num.columns[i:i+5],
                y_vars=['reading score'])

# %%
corr = data_num.drop('reading score', axis=1).corr()
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
data.corr()
# Out:
#                math score  reading score  writing score  Total_Marks  \
# math score       1.000000       0.817580       0.802642     0.918746
# reading score    0.817580       1.000000       0.954598     0.970331
# writing score    0.802642       0.954598       1.000000     0.965667
# Total_Marks      0.918746       0.970331       0.965667     1.000000
# Percentage       0.918746       0.970331       0.965667     1.000000
#
#                Percentage
# math score       0.918746
# reading score    0.970331
# writing score    0.965667
# Total_Marks      1.000000
# Percentage       1.000000

# %%
data['Total score']=data['math score']+data['reading score']+data['writing score']

# %%
data['math score']=pd.to_numeric(data['math score'],downcast='float')

# %%
print("Average math score is    : {}".format(np.mean(data['math score'])))
print("Average reading score is : {}".format(np.mean(data['reading score'])))
print("Average writing score is : {}".format(np.mean(data['writing score'])))
print("Average total score is   : {}".format(np.mean(data['Total score'])/3))
# Out:
# Average math score is    : 66.08899688720703
# Average reading score is : 69.169
# Average writing score is : 68.054
# Average total score is   : 67.77066666666667

# %%
plt.rcParams['axes.facecolor'] = "#b3ffff"
plt.rcParams['figure.facecolor'] ="#b3ffff"
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title('Math scores')
sns.violinplot(y='math score',data=data,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('Reading scores')
sns.violinplot(y='reading score',data=data,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('Writing scores')
sns.violinplot(y='writing score',data=data,color='blue',linewidth=3)
plt.show()

# %%
plt.rcParams['figure.facecolor'] = "#e6ecff"
plt.rcParams['axes.facecolor'] = "#e6ecff"
plt.figure(figsize=(14,8))
plt.subplot(1, 3, 1)
sns.barplot(x='test preparation course',y='math score',data=data,hue='gender',palette='seismic',**{'hatch':'*','alpha':0.6,'linewidth':2})
plt.title('MATH SCORES')
plt.subplot(1, 3, 2)
sns.barplot(x='test preparation course',y='reading score',data=data,hue='gender',palette='seismic',**{'hatch':'.','alpha':0.8,'linewidth':2})
plt.title('READING SCORES')
plt.subplot(1, 3, 3)
sns.barplot(x='test preparation course',y='writing score',data=data,hue='gender',palette='seismic',**{'hatch':'x','linewidth':2})
plt.title('WRITING SCORES')
plt.show()

# %%
plt.rcParams['axes.facecolor'] = "#ffe5e5"
plt.rcParams['figure.facecolor'] = "#ffe5e5"
sns.pairplot(data=data,hue='gender',plot_kws={'alpha':0.3},palette='muted')

# %%
corr = data.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(8, 8))
    ax = sns.heatmap(corr,mask=mask,square=True,linewidths=.8,cmap="autumn",annot=True)

# %%
sns.heatmap(data.corr(),cmap="Reds")

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(141)
plt.title('Gender',fontsize = 20)
data['gender'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(142)
plt.title('Ethinicity',fontsize = 20)
data['race/ethnicity'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(143)
plt.title('Lunch',fontsize = 20)
data['lunch'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(144)
plt.title('Parentel level of Education',fontsize = 20)
data['parental level of education'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
sns.heatmap(data.corr(),cmap="Reds")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0             72             74
# 1               completed        69.0             90             88
# 2                    none        90.0             95             93
# 3                    none        47.0             57             44
# 4                    none        76.0             78             75
#
#   Maths_pass Reading_pass Writing_pass  Total_Marks  Percentage  Total score
# ...

# %%
data['code']= pd.factorize(data.gender)[0]
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 995               completed        88.0             99             95
# 996                    none        62.0             55             55
# 997               completed        59.0             71             65
# 998               completed        68.0             78             77
# 999                    none        77.0             86             86
#
#     Maths_pass Reading_pass Writing_pass  Total_Marks  Percentage  \
# ...

# %%
data.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data.code.value_counts()
# Out:
# 0    518
# 1    482
# Name: code, dtype: int64

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0             72             74
# 1               completed        69.0             90             88
# 2                    none        90.0             95             93
# 3                    none        47.0             57             44
# 4                    none        76.0             78             75
#
#   Maths_pass Reading_pass Writing_pass  Total_Marks  Percentage  Total score  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
data['code_le']=le.fit_transform(data.gender)
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0             72             74
# 1               completed        69.0             90             88
# 2                    none        90.0             95             93
# 3                    none        47.0             57             44
# 4                    none        76.0             78             75
#
#   Maths_pass Reading_pass Writing_pass  Total_Marks  Percentage  Total score  \
# ...

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 995               completed        88.0             99             95
# 996                    none        62.0             55             55
# 997               completed        59.0             71             65
# 998               completed        68.0             78             77
# 999                    none        77.0             86             86
#
#     Maths_pass Reading_pass Writing_pass  Total_Marks  Percentage  \
# ...

# %%
#calculate correlation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy.stats.stats import pearsonr

# %%
sns.pairplot(data)

# %%
x= data[['code_le','reading score']]
sns.pairplot(x)

# %%
scipy.stats.pearsonr(data['code_le'],data['reading score'])
# Out:
# (-0.24431260787747175, 4.680538743933235e-15)

# %%
np.corrcoef(data['code_le'],data['reading score'])
# Out:
# array([[ 1.        , -0.24431261],
#        [-0.24431261,  1.        ]])

# %%
sns.heatmap(data.corr(),cmap="Reds")

# %%
data.corr()
# Out:
#                math score  reading score  writing score  Total_Marks  \
# math score       1.000000       0.817580       0.802642     0.918746
# reading score    0.817580       1.000000       0.954598     0.970331
# writing score    0.802642       0.954598       1.000000     0.965667
# Total_Marks      0.918746       0.970331       0.965667     1.000000
# Percentage       0.918746       0.970331       0.965667     1.000000
# Total score      0.918746       0.970331       0.965667     1.000000
# code             0.167982      -0.244313      -0.301225    -0.130861
# code_le          0.167982      -0.244313      -0.301225    -0.130861
#
#                Percentage  Total score      code   code_le
# math score       0.918746     0.918746  0.167982  0.167982
# reading score    0.970331     0.970331 -0.244313 -0.244313
# writing score    0.965667     0.965667 -0.301225 -0.301225
# Total_Marks      1.000000     1.000000 -0.130861 -0.130861
# ...

# %%
data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f992784a_59d3_11eb_bfa2_c858c0c13b4drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f992784a_59d3_11eb_bfa2_c858c0c13b4drow0_col1 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_f992784a_59d3_11eb_bfa2_c858c0c13b4drow0_col2 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_f992784a_59d3_11eb_bfa2_c858c0c13b4drow0_col3 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_f992784a_59d3_11eb_bfa2_c858c0c13b4drow0_col4 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_f992784a_59d3_11eb_bfa2_c858c0c13b4drow0_col5 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_f992784a_59d3_11eb_bfa2_c858c0c13b4drow0_col6 {
#             background-color:  #b3cdfb;
#             color:  #000000;
# ...

# %%
data1 = data['code_le']
data2= data['reading score']

# %%
data3 = data1+data2

# %%
sns.heatmap(data.corr(),cmap="Reds")

# %%
data.corr(method='pearson', min_periods=1)
# Out:
#                math score  reading score  writing score  Total_Marks  \
# math score       1.000000       0.817580       0.802642     0.918746
# reading score    0.817580       1.000000       0.954598     0.970331
# writing score    0.802642       0.954598       1.000000     0.965667
# Total_Marks      0.918746       0.970331       0.965667     1.000000
# Percentage       0.918746       0.970331       0.965667     1.000000
# Total score      0.918746       0.970331       0.965667     1.000000
# code             0.167982      -0.244313      -0.301225    -0.130861
# code_le          0.167982      -0.244313      -0.301225    -0.130861
#
#                Percentage  Total score      code   code_le
# math score       0.918746     0.918746  0.167982  0.167982
# reading score    0.970331     0.970331 -0.244313 -0.244313
# writing score    0.965667     0.965667 -0.301225 -0.301225
# Total_Marks      1.000000     1.000000 -0.130861 -0.130861
# ...
